# %%
from lyricsgenius import Genius
import Config
import pandas as pd
import os
import re

# %%
genius = Genius(Config.token) # Get your Access Token from the Genius API

# %%
artist = genius.search_artist("Taylor Swift", max_songs=5,  sort="popularity") #
# Out:
# Searching for songs by Taylor Swift...
#
# Song 1: "All Too Well (10 Minute Version) (Taylor’s Version) [From the Vault]"
# Song 2: "All Too Well (10 Minute Version) (Taylor’s Version) [Live Acoustic]"
# Song 3: "​cardigan"
# Song 4: "​exile"
# Song 5: "Lover"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.

# %%
genius.artist_albums(1177) # 1177 is the Artist ID
# Out:
# {'albums': [{'_type': 'album',
#    'api_path': '/albums/1027134',
#    'cover_art_thumbnail_url': 'https://images.genius.com/248810da165c73e40abd1cca5c967e4b.300x300x1.png',
#    'cover_art_url': 'https://images.genius.com/248810da165c73e40abd1cca5c967e4b.800x800x1.png',
#    'full_title': 'folklore: the long pond studio sessions (Record Store Day Exclusive) by Taylor Swift',
#    'id': 1027134,
#    'name': 'folklore: the long pond studio sessions (Record Store Day Exclusive)',
#    'name_with_artist': 'folklore: the long pond studio sessions (Record Store Day Exclusive) (artist: Taylor Swift)',
#    'release_date_components': {'year': 2023, 'month': 4, 'day': 22},
#    'release_date_for_display': 'April 22, 2023',
#    'url': 'https://genius.com/albums/Taylor-swift/Folklore-the-long-pond-studio-sessions-record-store-day-exclusive',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/1013719',
#    'cover_art_thumbnail_url': 'https://images.genius.com/6cd2944bb772417c6af2c2d6ae708768.300x300x1.jpg',
#    'cover_art_url': 'https://images.genius.com/6cd2944bb772417c6af2c2d6ae708768.1000x1000x1.jpg',
#    'full_title': 'The More Red (Taylor’s Version) Chapter by Taylor Swift',
#    'id': 1013719,
#    'name': 'The More Red (Taylor’s Version) Chapter',
#    'name_with_artist': 'The More Red (Taylor’s Version) Chapter (artist: Taylor Swift)',
#    'release_date_components': {'year': 2023, 'month': 3, 'day': 17},
#    'release_date_for_display': 'March 17, 2023',
#    'url': 'https://genius.com/albums/Taylor-swift/The-more-red-taylors-version-chapter',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/1013718',
#    'cover_art_thumbnail_url': 'https://images.genius.com/2c0c351eb486e375d437010ef3405a05.300x300x1.jpg',
#    'cover_art_url': 'https://images.genius.com/2c0c351eb486e375d437010ef3405a05.1000x1000x1.jpg',
#    'full_title': 'The More Fearless (Taylor’s Version) Chapter by Taylor Swift',
#    'id': 1013718,
#    'name': 'The More Fearless (Taylor’s Version) Chapter',
#    'name_with_artist': 'The More Fearless (Taylor’s Version) Chapter (artist: Taylor Swift)',
#    'release_date_components': {'year': 2023, 'month': 3, 'day': 17},
#    'release_date_for_display': 'March 17, 2023',
#    'url': 'https://genius.com/albums/Taylor-swift/The-more-fearless-taylors-version-chapter',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/1013715',
#    'cover_art_thumbnail_url': 'https://images.genius.com/2210e0b7ebb794bf97d6f6d1bcd103bd.300x300x1.png',
#    'cover_art_url': 'https://images.genius.com/2210e0b7ebb794bf97d6f6d1bcd103bd.1000x1000x1.png',
#    'full_title': 'The More Lover Chapter by Taylor Swift',
#    'id': 1013715,
#    'name': 'The More Lover Chapter',
#    'name_with_artist': 'The More Lover Chapter (artist: Taylor Swift)',
#    'release_date_components': {'year': 2023, 'month': 3, 'day': 17},
#    'release_date_for_display': 'March 17, 2023',
#    'url': 'https://genius.com/albums/Taylor-swift/The-more-lover-chapter',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/1008313',
#    'cover_art_thumbnail_url': 'https://images.genius.com/938f0e45f3cbf5b72a3ef630c672665c.300x300x1.jpg',
#    'cover_art_url': 'https://images.genius.com/938f0e45f3cbf5b72a3ef630c672665c.1000x1000x1.jpg',
#    'full_title': 'Lavender Haze (Remixes) by Taylor Swift',
#    'id': 1008313,
#    'name': 'Lavender Haze (Remixes)',
#    'name_with_artist': 'Lavender Haze (Remixes) (artist: Taylor Swift)',
#    'release_date_components': {'year': 2023, 'month': 3, 'day': 3},
#    'release_date_for_display': 'March 3, 2023',
#    'url': 'https://genius.com/albums/Taylor-swift/Lavender-haze-remixes',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/969188',
#    'cover_art_thumbnail_url': 'https://images.genius.com/a119178e55799bf5a6a63f08c2987a3b.300x300x1.jpg',
#    'cover_art_url': 'https://images.genius.com/a119178e55799bf5a6a63f08c2987a3b.1000x1000x1.jpg',
#    'full_title': 'Anti-Hero (Remixes)  by Taylor Swift',
#    'id': 969188,
#    'name': 'Anti-Hero (Remixes) ',
#    'name_with_artist': 'Anti-Hero (Remixes)  (artist: Taylor Swift)',
#    'release_date_components': {'year': 2022, 'month': 11, 'day': 11},
#    'release_date_for_display': 'November 11, 2022',
#    'url': 'https://genius.com/albums/Taylor-swift/Anti-hero-remixes',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/949856',
#    'cover_art_thumbnail_url': 'https://images.genius.com/2ed72f4e721a9d2112cd0471e4c130dc.300x300x1.png',
#    'cover_art_url': 'https://images.genius.com/2ed72f4e721a9d2112cd0471e4c130dc.1000x1000x1.png',
#    'full_title': 'Midnights (Target Exclusive) by Taylor Swift',
#    'id': 949856,
#    'name': 'Midnights (Target Exclusive)',
#    'name_with_artist': 'Midnights (Target Exclusive) (artist: Taylor Swift)',
#    'release_date_components': {'year': 2022, 'month': 10, 'day': 21},
#    'release_date_for_display': 'October 21, 2022',
#    'url': 'https://genius.com/albums/Taylor-swift/Midnights-target-exclusive',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/962334',
#    'cover_art_thumbnail_url': 'https://images.genius.com/28417d8f2f4d5da33ae32dd2ec8f0d4c.300x300x1.jpg',
#    'cover_art_url': 'https://images.genius.com/28417d8f2f4d5da33ae32dd2ec8f0d4c.1000x1000x1.jpg',
#    'full_title': 'Midnights (3am Edition) by Taylor Swift',
#    'id': 962334,
#    'name': 'Midnights (3am Edition)',
#    'name_with_artist': 'Midnights (3am Edition) (artist: Taylor Swift)',
#    'release_date_components': {'year': 2022, 'month': 10, 'day': 21},
#    'release_date_for_display': 'October 21, 2022',
#    'url': 'https://genius.com/albums/Taylor-swift/Midnights-3am-edition',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/945000',
#    'cover_art_thumbnail_url': 'https://images.genius.com/395eb4a5e6aa04c8574425345cd816f5.300x300x1.png',
#    'cover_art_url': 'https://images.genius.com/395eb4a5e6aa04c8574425345cd816f5.894x894x1.png',
#    'full_title': 'Midnights by Taylor Swift',
#    'id': 945000,
#    'name': 'Midnights',
#    'name_with_artist': 'Midnights (artist: Taylor Swift)',
#    'release_date_components': {'year': 2022, 'month': 10, 'day': 21},
#    'release_date_for_display': 'October 21, 2022',
#    'url': 'https://genius.com/albums/Taylor-swift/Midnights',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/959034',
#    'cover_art_thumbnail_url': 'https://images.genius.com/8cb6f325228abfe375bb25721e9c211e.300x300x1.jpg',
#    'cover_art_url': 'https://images.genius.com/8cb6f325228abfe375bb25721e9c211e.1000x1000x1.jpg',
#    'full_title': 'Midnights (Apple Music Exclusive)  by Taylor Swift',
#    'id': 959034,
#    'name': 'Midnights (Apple Music Exclusive) ',
#    'name_with_artist': 'Midnights (Apple Music Exclusive)  (artist: Taylor Swift)',
#    'release_date_components': {'year': 2022, 'month': 10, 'day': 21},
#    'release_date_for_display': 'October 21, 2022',
#    'url': 'https://genius.com/albums/Taylor-swift/Midnights-apple-music-exclusive',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/921019',
#    'cover_art_thumbnail_url': 'https://images.genius.com/a183a4b542c37d5518c12a68305bbeb1.300x300x1.png',
#    'cover_art_url': 'https://images.genius.com/a183a4b542c37d5518c12a68305bbeb1.1000x1000x1.png',
#    'full_title': 'Carolina (From The Motion Picture “Where The Crawdads Sing”) by Taylor Swift',
#    'id': 921019,
#    'name': 'Carolina (From The Motion Picture “Where The Crawdads Sing”)',
#    'name_with_artist': 'Carolina (From The Motion Picture “Where The Crawdads Sing”) (artist: Taylor Swift)',
#    'release_date_components': {'year': 2022, 'month': 6, 'day': 24},
#    'release_date_for_display': 'June 24, 2022',
#    'url': 'https://genius.com/albums/Taylor-swift/Carolina-from-the-motion-picture-where-the-crawdads-sing',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/916591',
#    'cover_art_thumbnail_url': 'https://images.genius.com/52e2cfe424ca111515b7db2f63c7c7fc.300x300x1.jpg',
#    'cover_art_url': 'https://images.genius.com/52e2cfe424ca111515b7db2f63c7c7fc.1000x1000x1.jpg',
#    'full_title': 'All Too Well (10 Minute Version) [The Short Film] - EP by Taylor Swift',
#    'id': 916591,
#    'name': 'All Too Well (10 Minute Version) [The Short Film] - EP',
#    'name_with_artist': 'All Too Well (10 Minute Version) [The Short Film] - EP (artist: Taylor Swift)',
#    'release_date_components': {'year': 2022, 'month': 6, 'day': 11},
#    'release_date_for_display': 'June 11, 2022',
#    'url': 'https://genius.com/albums/Taylor-swift/All-too-well-10-minute-version-the-short-film-ep',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/873527',
#    'cover_art_thumbnail_url': 'https://images.genius.com/07912c897401e2a8e055e4d3fbef58e4.300x300x1.jpg',
#    'cover_art_url': 'https://images.genius.com/07912c897401e2a8e055e4d3fbef58e4.1000x1000x1.jpg',
#    'full_title': 'the lakes - 7" Single (Record Store Day Exclusive) by Taylor Swift',
#    'id': 873527,
#    'name': 'the lakes - 7" Single (Record Store Day Exclusive)',
#    'name_with_artist': 'the lakes - 7" Single (Record Store Day Exclusive) (artist: Taylor Swift)',
#    'release_date_components': {'year': 2022, 'month': 4, 'day': 23},
#    'release_date_for_display': 'April 23, 2022',
#    'url': 'https://genius.com/albums/Taylor-swift/The-lakes-7-single-record-store-day-exclusive',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/862870',
#    'cover_art_thumbnail_url': 'https://images.genius.com/20d0bfa8bc8f9a57292dbdfee17fb7a5.300x300x1.png',
#    'cover_art_url': 'https://images.genius.com/20d0bfa8bc8f9a57292dbdfee17fb7a5.1000x1000x1.png',
#    'full_title': 'Red (Taylor’s Version): From The Vault Chapter  by Taylor Swift',
#    'id': 862870,
#    'name': 'Red (Taylor’s Version): From The Vault Chapter ',
#    'name_with_artist': 'Red (Taylor’s Version): From The Vault Chapter  (artist: Taylor Swift)',
#    'release_date_components': {'year': 2022, 'month': 1, 'day': 31},
#    'release_date_for_display': 'January 31, 2022',
#    'url': 'https://genius.com/albums/Taylor-swift/Red-taylors-version-from-the-vault-chapter',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/862869',
#    'cover_art_thumbnail_url': 'https://images.genius.com/b619aca519159a36bcc59789ec58a423.300x300x1.png',
#    'cover_art_url': 'https://images.genius.com/b619aca519159a36bcc59789ec58a423.1000x1000x1.png',
#    'full_title': 'Red (Taylor’s Version): The Slow Motion Chapter  by Taylor Swift',
#    'id': 862869,
#    'name': 'Red (Taylor’s Version): The Slow Motion Chapter ',
#    'name_with_artist': 'Red (Taylor’s Version): The Slow Motion Chapter  (artist: Taylor Swift)',
#    'release_date_components': {'year': 2022, 'month': 1, 'day': 25},
#    'release_date_for_display': 'January 25, 2022',
#    'url': 'https://genius.com/albums/Taylor-swift/Red-taylors-version-the-slow-motion-chapter',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/862783',
#    'cover_art_thumbnail_url': 'https://images.genius.com/736391200b2e99e5b349b233e875ce57.300x300x1.png',
#    'cover_art_url': 'https://images.genius.com/736391200b2e99e5b349b233e875ce57.1000x1000x1.png',
#    'full_title': 'Message In A Bottle (Fat Max G Remix) (Taylor’s Version)  by Taylor Swift',
#    'id': 862783,
#    'name': 'Message In A Bottle (Fat Max G Remix) (Taylor’s Version) ',
#    'name_with_artist': 'Message In A Bottle (Fat Max G Remix) (Taylor’s Version)  (artist: Taylor Swift)',
#    'release_date_components': {'year': 2022, 'month': 1, 'day': 21},
#    'release_date_for_display': 'January 21, 2022',
#    'url': 'https://genius.com/albums/Taylor-swift/Message-in-a-bottle-fat-max-g-remix-taylors-version',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/861675',
#    'cover_art_thumbnail_url': 'https://images.genius.com/309a53812327c49099e39f1e2a511f6d.300x300x1.png',
#    'cover_art_url': 'https://images.genius.com/309a53812327c49099e39f1e2a511f6d.1000x1000x1.png',
#    'full_title': 'Red (Taylor’s Version): She Wrote A Song About Me Chapter by Taylor Swift',
#    'id': 861675,
#    'name': 'Red (Taylor’s Version): She Wrote A Song About Me Chapter',
#    'name_with_artist': 'Red (Taylor’s Version): She Wrote A Song About Me Chapter (artist: Taylor Swift)',
#    'release_date_components': {'year': 2022, 'month': 1, 'day': 18},
#    'release_date_for_display': 'January 18, 2022',
#    'url': 'https://genius.com/albums/Taylor-swift/Red-taylors-version-she-wrote-a-song-about-me-chapter',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/859646',
#    'cover_art_thumbnail_url': 'https://images.genius.com/a9300545e1d5280a37c2b15b28228e48.300x300x1.png',
#    'cover_art_url': 'https://images.genius.com/a9300545e1d5280a37c2b15b28228e48.1000x1000x1.png',
#    'full_title': 'Red (Taylor’s Version): Could You Be The One Chapter by Taylor Swift',
#    'id': 859646,
#    'name': 'Red (Taylor’s Version): Could You Be The One Chapter',
#    'name_with_artist': 'Red (Taylor’s Version): Could You Be The One Chapter (artist: Taylor Swift)',
#    'release_date_components': {'year': 2022, 'month': 1, 'day': 13},
#    'release_date_for_display': 'January 13, 2022',
#    'url': 'https://genius.com/albums/Taylor-swift/Red-taylors-version-could-you-be-the-one-chapter',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/758022',
#    'cover_art_thumbnail_url': 'https://images.genius.com/7809d535eef0145a98d1ef1d5fbe4391.300x300x1.jpg',
#    'cover_art_url': 'https://images.genius.com/7809d535eef0145a98d1ef1d5fbe4391.1000x1000x1.jpg',
#    'full_title': 'Red (Taylor’s Version) by Taylor Swift',
#    'id': 758022,
#    'name': 'Red (Taylor’s Version)',
#    'name_with_artist': 'Red (Taylor’s Version) (artist: Taylor Swift)',
#    'release_date_components': {'year': 2021, 'month': 11, 'day': 12},
#    'release_date_for_display': 'November 12, 2021',
#    'url': 'https://genius.com/albums/Taylor-swift/Red-taylors-version',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/779383',
#    'cover_art_thumbnail_url': 'https://images.genius.com/51293ede64dafece331990941aee995e.300x300x1.jpg',
#    'cover_art_url': 'https://images.genius.com/51293ede64dafece331990941aee995e.1000x1000x1.jpg',
#    'full_title': 'evermore (digitally autographed fan edition) by Taylor Swift',
#    'id': 779383,
#    'name': 'evermore (digitally autographed fan edition)',
#    'name_with_artist': 'evermore (digitally autographed fan edition) (artist: Taylor Swift)',
#    'release_date_components': {'year': 2021, 'month': 6, 'day': 3},
#    'release_date_for_display': 'June 3, 2021',
#    'url': 'https://genius.com/albums/Taylor-swift/Evermore-digitally-autographed-fan-edition',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/776228',
#    'cover_art_thumbnail_url': 'https://images.genius.com/6e8347db27bc215449ee194dca841bb5.300x300x1.jpg',
#    'cover_art_url': 'https://images.genius.com/6e8347db27bc215449ee194dca841bb5.512x512x1.jpg',
#    'full_title': 'Fearless (Taylor’s Version): The From the Vault Chapter by Taylor Swift',
#    'id': 776228,
#    'name': 'Fearless (Taylor’s Version): The From the Vault Chapter',
#    'name_with_artist': 'Fearless (Taylor’s Version): The From the Vault Chapter (artist: Taylor Swift)',
#    'release_date_components': {'year': 2021, 'month': 5, 'day': 26},
#    'release_date_for_display': 'May 26, 2021',
#    'url': 'https://genius.com/albums/Taylor-swift/Fearless-taylors-version-the-from-the-vault-chapter',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/775761',
#    'cover_art_thumbnail_url': 'https://images.genius.com/935ea51a7bf55d246b9523f35ec51a19.300x300x1.jpg',
#    'cover_art_url': 'https://images.genius.com/935ea51a7bf55d246b9523f35ec51a19.512x512x1.jpg',
#    'full_title': 'Fearless (Taylor’s Version): The I Remember What You Said Last Night Chapter by Taylor Swift',
#    'id': 775761,
#    'name': 'Fearless (Taylor’s Version): The I Remember What You Said Last Night Chapter',
#    'name_with_artist': 'Fearless (Taylor’s Version): The I Remember What You Said Last Night Chapter (artist: Taylor Swift)',
#    'release_date_components': {'year': 2021, 'month': 5, 'day': 24},
#    'release_date_for_display': 'May 24, 2021',
#    'url': 'https://genius.com/albums/Taylor-swift/Fearless-taylors-version-the-i-remember-what-you-said-last-night-chapter',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/773617',
#    'cover_art_thumbnail_url': 'https://images.genius.com/b4d90a020a69bb9a73c310f9649ce591.300x300x1.jpg',
#    'cover_art_url': 'https://images.genius.com/b4d90a020a69bb9a73c310f9649ce591.512x512x1.jpg',
#    'full_title': 'Fearless (Taylor’s Version): The Kissing In The Rain Chapter by Taylor Swift',
#    'id': 773617,
#    'name': 'Fearless (Taylor’s Version): The Kissing In The Rain Chapter',
#    'name_with_artist': 'Fearless (Taylor’s Version): The Kissing In The Rain Chapter (artist: Taylor Swift)',
#    'release_date_components': {'year': 2021, 'month': 5, 'day': 19},
#    'release_date_for_display': 'May 19, 2021',
#    'url': 'https://genius.com/albums/Taylor-swift/Fearless-taylors-version-the-kissing-in-the-rain-chapter',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/771313',
#    'cover_art_thumbnail_url': 'https://images.genius.com/3410b6f873b83e5589b4957e0826aa8a.300x300x1.jpg',
#    'cover_art_url': 'https://images.genius.com/3410b6f873b83e5589b4957e0826aa8a.512x512x1.jpg',
#    'full_title': "Fearless (Taylor's Version): The Halfway Out the Door Chapter by Taylor Swift",
#    'id': 771313,
#    'name': 'Fearless (Taylor’s Version): The Halfway Out the Door Chapter',
#    'name_with_artist': "Fearless (Taylor's Version): The Halfway Out the Door Chapter (artist: Taylor Swift)",
#    'release_date_components': {'year': 2021, 'month': 5, 'day': 13},
#    'release_date_for_display': 'May 13, 2021',
#    'url': 'https://genius.com/albums/Taylor-swift/Fearless-taylor-s-version-the-halfway-out-the-door-chapter',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/734107',
#    'cover_art_thumbnail_url': 'https://images.genius.com/cb3e5556ace37f591ee4247fb36ba50b.300x300x1.jpg',
#    'cover_art_url': 'https://images.genius.com/cb3e5556ace37f591ee4247fb36ba50b.1000x1000x1.jpg',
#    'full_title': "Fearless (Taylor's Version) by Taylor Swift",
#    'id': 734107,
#    'name': 'Fearless (Taylor’s Version)',
#    'name_with_artist': "Fearless (Taylor's Version) (artist: Taylor Swift)",
#    'release_date_components': {'year': 2021, 'month': 4, 'day': 9},
#    'release_date_for_display': 'April 9, 2021',
#    'url': 'https://genius.com/albums/Taylor-swift/Fearless-taylor-s-version',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/731261',
#    'cover_art_thumbnail_url': 'https://images.genius.com/89508959e0cba1fc671810715a130802.300x300x1.png',
#    'cover_art_url': 'https://images.genius.com/89508959e0cba1fc671810715a130802.1000x1000x1.png',
#    'full_title': 'the “ladies lunching” chapter by Taylor Swift',
#    'id': 731261,
#    'name': 'the “ladies lunching” chapter',
#    'name_with_artist': 'the “ladies lunching” chapter (artist: Taylor Swift)',
#    'release_date_components': {'year': 2021, 'month': 2, 'day': 4},
#    'release_date_for_display': 'February 4, 2021',
#    'url': 'https://genius.com/albums/Taylor-swift/The-ladies-lunching-chapter',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/728549',
#    'cover_art_thumbnail_url': 'https://images.genius.com/6c6b733beb9cd1d15e6c10e7da8ce3f2.300x300x1.jpg',
#    'cover_art_url': 'https://images.genius.com/6c6b733beb9cd1d15e6c10e7da8ce3f2.1000x1000x1.jpg',
#    'full_title': 'evermore: the “forever is the sweetest con” chapter by Taylor Swift',
#    'id': 728549,
#    'name': 'evermore: the “forever is the sweetest con” chapter',
#    'name_with_artist': 'evermore: the “forever is the sweetest con” chapter (artist: Taylor Swift)',
#    'release_date_components': {'year': 2021, 'month': 1, 'day': 28},
#    'release_date_for_display': 'January 28, 2021',
#    'url': 'https://genius.com/albums/Taylor-swift/Evermore-the-forever-is-the-sweetest-con-chapter',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/725953',
#    'cover_art_thumbnail_url': 'https://images.genius.com/8a23c2854df16976c8b4b6371b78be04.300x300x1.jpg',
#    'cover_art_url': 'https://images.genius.com/8a23c2854df16976c8b4b6371b78be04.512x512x1.jpg',
#    'full_title': 'evermore: the dropped your hand while dancing chapter by Taylor Swift',
#    'id': 725953,
#    'name': 'evermore: the dropped your hand while dancing chapter',
#    'name_with_artist': 'evermore: the dropped your hand while dancing chapter (artist: Taylor Swift)',
#    'release_date_components': {'year': 2021, 'month': 1, 'day': 21},
#    'release_date_for_display': 'January 21, 2021',
#    'url': 'https://genius.com/albums/Taylor-swift/Evermore-the-dropped-your-hand-while-dancing-chapter',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/710147',
#    'cover_art_thumbnail_url': 'https://images.genius.com/a43146535419531bcf8b9dca82c68f85.300x300x1.png',
#    'cover_art_url': 'https://images.genius.com/a43146535419531bcf8b9dca82c68f85.1000x1000x1.png',
#    'full_title': 'evermore (deluxe version) by Taylor Swift',
#    'id': 710147,
#    'name': 'evermore (deluxe version)',
#    'name_with_artist': 'evermore (deluxe version) (artist: Taylor Swift)',
#    'release_date_components': {'year': 2021, 'month': 1, 'day': 7},
#    'release_date_for_display': 'January 7, 2021',
#    'url': 'https://genius.com/albums/Taylor-swift/Evermore-deluxe-version',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}},
#   {'_type': 'album',
#    'api_path': '/albums/726425',
#    'cover_art_thumbnail_url': 'https://images.genius.com/a43146535419531bcf8b9dca82c68f85.300x300x1.png',
#    'cover_art_url': 'https://images.genius.com/a43146535419531bcf8b9dca82c68f85.1000x1000x1.png',
#    'full_title': 'evermore (Japanese Edition) by Taylor Swift',
#    'id': 726425,
#    'name': 'evermore (Japanese Edition)',
#    'name_with_artist': 'evermore (Japanese Edition) (artist: Taylor Swift)',
#    'release_date_components': {'year': 2021, 'month': 1, 'day': None},
#    'release_date_for_display': 'January 2021',
#    'url': 'https://genius.com/albums/Taylor-swift/Evermore-japanese-edition',
#    'artist': {'_type': 'artist',
#     'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/a74ab9ea8f7314b6e015133c5bd0314a.1000x333x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/866d31e6a0fb376d0117018b5913369f.1000x1000x1.png',
#     'index_character': 't',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Taylor Swift',
#     'slug': 'Taylor-swift',
#     'url': 'https://genius.com/artists/Taylor-swift',
#     'iq': 1544}}],
#  'next_page': 2}

# %%
album_dict = genius.artist_albums(1177)

# %%
len(album_dict['albums'])
# Out:
# 30

# %%
album_lis = []
for ele in album_dict['albums']:

    id = ele['id']
    album = ele['name']
    album_lis.append([id,album])

# %%
album_df = pd.DataFrame(album_lis,columns=['ID','Albums'])

# %%
dict = {'ID':12682,'Albums':'Taylor Swift'}
album_df = album_df.append(dict, ignore_index=True)

dict = {'ID':350177,'Albums':'Fearless (Platinum Edition)'}
album_df = album_df.append(dict, ignore_index=True)

dict = {'ID':597883,'Albums':'Speak Now (Deluxe)'}
album_df = album_df.append(dict, ignore_index=True)

dict = {'ID':22453,'Albums':'Red'}
album_df = album_df.append(dict, ignore_index=True)

dict = {'ID':110728,'Albums':'1989'}
album_df = album_df.append(dict, ignore_index=True)

dict = {'ID':350247,'Albums':'Reputation'}
album_df = album_df.append(dict, ignore_index=True)

dict = {'ID':520929,'Albums':'Lover'}
album_df = album_df.append(dict, ignore_index=True)

dict = {'ID':659925,'Albums':'Folklore'}
album_df = album_df.append(dict, ignore_index=True)

dict = {'ID':710140,'Albums':'Evermore'}
album_df = album_df.append(dict, ignore_index=True)

dict = {'ID':10982,'Albums':'Speak Now'}
album_df = album_df.append(dict, ignore_index=True)

ict = {'ID':12731,'Albums':'Fearless'}
album_df = album_df.append(dict, ignore_index=True)

dict = {'ID':14637,'Albums':'Speak Now: World Tour Live'}
album_df = album_df.append(dict, ignore_index=True)

# %%
len(album_df)
# Out:
# 42

# %%
album_df.head()
# Out:
#         ID                                             Albums
# 0  1027134  folklore: the long pond studio sessions (Recor...
# 1  1013719            The More Red (Taylor’s Version) Chapter
# 2  1013718       The More Fearless (Taylor’s Version) Chapter
# 3  1013715                             The More Lover Chapter
# 4  1008313                            Lavender Haze (Remixes)

# %%
for i in range(0,len(album_df)):
    album_id = album_df.iloc[i,0]
    album_unicode = album_df.iloc[i,1]
    album_encode = album_unicode.encode("ascii","ignore")
    album = album_encode.decode()
    album_dirname = re.sub('[^a-zA-Z0-9_]','_',''.join(album.split())) 


    album_path = 'data/Albums/{}'.format(album_dirname)
    isExist = os.path.exists(album_path)
    if not isExist:
        os.makedirs(album_path)
    else:
        print('ALBUM {} exists'.format(album))
        continue

    tracks_dict = genius.album_tracks(album_id)

    track_lis = []
    for ele in tracks_dict['tracks']:
        track_id = ele['song']['id']
        track_unicode = ele['song']['title']
        track_encode = track_unicode.encode("ascii","ignore")
        track_name = track_encode.decode()

        track_lis.append([track_id,track_name])

        song_dict = genius.search_song(track_unicode, artist.name)
        try:
            lyrics_txt = song_dict.lyrics
        except AttributeError:
            print('TRACK {} lyrics dont exist'.format(track_name))
            
        lyric_lis = lyrics_txt.split('\n')
        track_filename = re.sub('[^a-zA-Z0-9_]','_',''.join(track_name.split())) + '.txt'
        try:
            track_path = os.path.join(album_path,track_filename)
            f = open(track_path,'w')
            f.write(lyrics_txt)
            f.close()
        except FileExistsError:
            print('File already exists')
# Out:
# ALBUM folklore: the long pond studio sessions (Record Store Day Exclusive) exists
# ALBUM The More Red (Taylors Version) Chapter exists
# ALBUM The More Fearless (Taylors Version) Chapter exists
# ALBUM The More Lover Chapter exists
# ALBUM Lavender Haze (Remixes) exists
# ALBUM Anti-Hero (Remixes)  exists
# ALBUM Midnights (Target Exclusive) exists
# ALBUM Midnights (3am Edition) exists
# ALBUM Midnights exists
# ALBUM Midnights (Apple Music Exclusive)  exists
# ALBUM Carolina (From The Motion Picture Where The Crawdads Sing) exists
# ALBUM All Too Well (10 Minute Version) [The Short Film] - EP exists
# ALBUM the lakes - 7" Single (Record Store Day Exclusive) exists
# ALBUM Red (Taylors Version): From The Vault Chapter  exists
# ALBUM Red (Taylors Version): The Slow Motion Chapter  exists
# ALBUM Message In A Bottle (Fat Max G Remix) (Taylors Version)  exists
# ALBUM Red (Taylors Version): She Wrote A Song About Me Chapter exists
# ALBUM Red (Taylors Version): Could You Be The One Chapter exists
# ALBUM Red (Taylors Version) exists
# ALBUM evermore (digitally autographed fan edition) exists
# ALBUM Fearless (Taylors Version): The From the Vault Chapter exists
# ALBUM Fearless (Taylors Version): The I Remember What You Said Last Night Chapter exists
# ALBUM Fearless (Taylors Version): The Kissing In The Rain Chapter exists
# ALBUM Fearless (Taylors Version): The Halfway Out the Door Chapter exists
# ALBUM Fearless (Taylors Version) exists
# ALBUM the ladies lunching chapter exists
# ALBUM evermore: the forever is the sweetest con chapter exists
# ALBUM evermore: the dropped your hand while dancing chapter exists
# ALBUM evermore (deluxe version) exists
# ALBUM evermore (Japanese Edition) exists
# ALBUM Taylor Swift exists
# ALBUM Fearless (Platinum Edition) exists
# ALBUM Speak Now (Deluxe) exists
# ALBUM Red exists
# ALBUM 1989 exists
# ALBUM Reputation exists
# ALBUM Lover exists
# ALBUM Folklore exists
# ALBUM Evermore exists
# ALBUM Speak Now exists
# ALBUM Speak Now exists
# ALBUM Speak Now: World Tour Live exists

# %%
album_df.head(15)
# Out:
#          ID                                             Albums
# 0   1027134  folklore: the long pond studio sessions (Recor...
# 1   1013719            The More Red (Taylor’s Version) Chapter
# 2   1013718       The More Fearless (Taylor’s Version) Chapter
# 3   1013715                             The More Lover Chapter
# 4   1008313                            Lavender Haze (Remixes)
# 5    969188                               Anti-Hero (Remixes)
# 6    949856                       Midnights (Target Exclusive)
# 7    962334                            Midnights (3am Edition)
# 8    945000                                          Midnights
# 9    959034                 Midnights (Apple Music Exclusive)
# 10   921019  Carolina (From The Motion Picture “Where The C...
# 11   916591  All Too Well (10 Minute Version) [The Short Fi...
# 12   873527  the lakes - 7" Single (Record Store Day Exclus...
# 13   862870    Red (Taylor’s Version): From The Vault Chapter
# 14   862869   Red (Taylor’s Version): The Slow Motion Chapter

# %%
album_df.iloc[15:27,:]
# Out:
#         ID                                             Albums
# 15  862783  Message In A Bottle (Fat Max G Remix) (Taylor’...
# 16  861675  Red (Taylor’s Version): She Wrote A Song About...
# 17  859646  Red (Taylor’s Version): Could You Be The One C...
# 18  758022                             Red (Taylor’s Version)
# 19  779383       evermore (digitally autographed fan edition)
# 20  776228  Fearless (Taylor’s Version): The From the Vaul...
# 21  775761  Fearless (Taylor’s Version): The I Remember Wh...
# 22  773617  Fearless (Taylor’s Version): The Kissing In Th...
# 23  771313  Fearless (Taylor’s Version): The Halfway Out t...
# 24  734107                        Fearless (Taylor’s Version)
# 25  731261                      the “ladies lunching” chapter
# 26  728549  evermore: the “forever is the sweetest con” ch...

# %%
album_df.tail(15)
# Out:
#         ID                                             Albums
# 27  725953  evermore: the dropped your hand while dancing ...
# 28  710147                          evermore (deluxe version)
# 29  726425                        evermore (Japanese Edition)
# 30   12682                                       Taylor Swift
# 31  350177                        Fearless (Platinum Edition)
# 32  597883                                 Speak Now (Deluxe)
# 33   22453                                                Red
# 34  110728                                               1989
# 35  350247                                         Reputation
# 36  520929                                              Lover
# 37  659925                                           Folklore
# 38  710140                                           Evermore
# 39   10982                                          Speak Now
# 40   10982                                          Speak Now
# 41   14637                         Speak Now: World Tour Live

# %%
def make_track_df(album_id, df_name):
    tracks_dict = genius.album_tracks(album_id)

    track_lis = []
    for ele in tracks_dict['tracks']:
        track_id = ele['song']['id']
        track_unicode = ele['song']['title']
        track_encode = track_unicode.encode("ascii","ignore")
        track_name = track_encode.decode()

        track_lis.append([track_id,track_name])
    df = pd.DataFrame(track_lis,columns=['ID','Tracks'])
    df.to_csv(df_name)

# %%
for i in range(0,len(album_df)):
    album_name = album_df.iloc[i,1]
    album_id = album_df.iloc[i,0]
    album_df_name = re.sub('[^a-zA-Z0-9_]','_',''.join(album_name.split())) + '.csv'
    path = 'data/Tabular/'+ album_df_name
    make_track_df(album_id, path)

# %%
album_df.to_csv('data/Albums.csv')
